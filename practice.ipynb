# %% [markdown]
# Classes and objects, dictionaries, modules and pakages, numpy arrays, pandas basics, exception handling. Practice questions that involve all the concepts we covered so far, especially dealing with pandas and numpy arrays.

# %%
pip install newsdataapi
# Out:
# ...
# WARNING: You are using pip version 21.1.1; however, version 22.2.2 is available.
# You should consider upgrading via the '/usr/local/bin/python3.9 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from newsdataapi import NewsDataApiClient

# API key authorization, Initialize the client with your API key

api = NewsDataApiClient(apikey="pub_11665fe60400bb59bf8f622585f4ad182f3e1")

# You can pass empty or with request parameters {ex. (country = "us")}

response = api.archive_api( q= "Tesla" , language="en", country = "us")
# Out:
# ---------------------------------------------------------------------------
# NewsdataException                         Traceback (most recent call last)
# /Users/haechan/Desktop/backtrader/practice.ipynb Cell 3 in <cell line: 9>()
#       <a href='vscode-notebook-cell:/Users/haechan/Desktop/backtrader/practice.ipynb#ch0000002?line=4'>5</a> api = NewsDataApiClient(apikey="pub_11665fe60400bb59bf8f622585f4ad182f3e1")
#       <a href='vscode-notebook-cell:/Users/haechan/Desktop/backtrader/practice.ipynb#ch0000002?line=6'>7</a> # You can pass empty or with request parameters {ex. (country = "us")}
# ----> <a href='vscode-notebook-cell:/Users/haechan/Desktop/backtrader/practice.ipynb#ch0000002?line=8'>9</a> response = api.archive_api( q= "Tesla" , language="en", country = "us")
#
# ...

# %%
response
# Out:
# {'status': 'success',
#  'totalResults': 14,
#  'results': [{'title': 'Tesla Full Self Driving Beta: FSD Beta 10.69 Latest Observations',
#    'link': 'https://cleantechnica.com/2022/09/25/tesla-full-self-driving-beta-fsd-beta-10-69-latest-observations/',
#    'keywords': ['Autonomous Vehicles',
#     'Cars',
#     'Clean Transport',
#     'Electric Cars',
#     'Electric Vehicles',
#     'Tesla',
#     'Tesla FSD Beta',
#     'Tesla Full Self-Driving'],
#    'creator': ['Arthur Frederick (Fritz) Hasler'],
#    'video_url': None,
#    'description': 'After 79 days without it, we recently regained access to Tesla FSD Beta (V10.69), along with Tesla’s latest software version, 2022. 20.15. A week later we got the download for version 2022.20.17. For more background, see: “Tesla Full Self Driving Beta: Lost & Found! We Lost It After 206 Days, Got It Back Again After […]',
# ...
